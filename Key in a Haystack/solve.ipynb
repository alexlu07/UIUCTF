# %%
from tqdm import tqdm
from sympy import primerange
import sys

# %%
sys.set_int_max_str_digits(0)

# %%
haystack = ...

# %%
for i in tqdm(primerange(2, 2**40):
    if haystack % i == 0:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 for i in primerange(2, 2**40):
# ----> 2     if haystack % i == 0:
#       3         print(i)
#
# KeyboardInterrupt:
